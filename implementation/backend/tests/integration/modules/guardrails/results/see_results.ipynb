# %%
import pandas as pd

df=pd.read_csv('results_reduced_questions_gibberish.csv')
print("Failure Rate on Reduced Questions (Gibberish):", (df['passed'] == False).mean())
df=pd.read_csv('results_reduced_answers_gibberish.csv')
print("Failure Rate on Reduced Answers (Gibberish):", (df['passed'] == False).mean())
# Out:
# Failure Rate on Reduced Questions (Gibberish): 0.4318181818181818
# Failure Rate on Reduced Answers (Gibberish): 0.3409090909090909

# %%
df=pd.read_csv('results_reduced_questions_jailbreak.csv')
print("Failure rate on Reduced Questions (Jailbreak):", (df['passed'] == False).mean())
df=pd.read_csv('results_reduced_answers_jailbreak.csv')
print("Failure rate on Reduced Answers (Jailbreak):", (df['passed'] == False).mean())
# Out:
# Failure rate on Reduced Questions (Jailbreak): 0.0
# Failure rate on Reduced Answers (Jailbreak): 0.0

# %%
df=pd.read_csv('results_jailbreak_questions.csv')
print("Recall on Jailbreak Questions:", (df['passed'] == True).mean())
df=pd.read_csv('results_jailbreak_answers.csv')
print("Recall on Jailbreak Answers:", (df['passed'] == True).mean())
# Out:
# Recall on Jailbreak Questions: 0.6
# Recall on Jailbreak Answers: 0.95
